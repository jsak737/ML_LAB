# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Update the path if needed
df = pd.read_csv('/content/drive/MyDrive/Dataset of Diabetes .csv')

# Display first 5 rows
df.head()
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
# Dataset information
df.info()

# Statistical summary
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    340.500000  2.705514e+05    53.528000     5.124743    68.943000
# std     240.397673  3.380758e+06     8.799241     2.935165    59.984747
# min       1.000000  1.230000e+02    20.000000     0.500000     6.000000
# 25%     125.750000  2.406375e+04    51.000000     3.700000    48.000000
# 50%     300.500000  3.439550e+04    55.000000     4.600000    60.000000
# 75%     550.250000  4.538425e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      8.281160     4.862820     2.349610     1.204750     2.609790
# std       2.534003     1.301738     1.401176     0.660414     1.115102
# min       0.900000     0.000000     0.300000     0.200000     0.300000
# 25%       6.500000     4.000000     1.500000     0.900000     1.800000
# 50%       8.000000     4.800000     2.000000     1.100000     2.500000
# 75%      10.200000     5.600000     2.900000     1.300000     3.300000
# max      16.000000    10.300000    13.800000     9.900000     9.900000
#
#               VLDL          BMI
# count  1000.000000  1000.000000
# mean      1.854700    29.578020
# std       3.663599     4.962388
# min       0.100000    19.000000
# 25%       0.700000    26.000000
# 50%       0.900000    30.000000
# 75%       1.500000    33.000000
# max      35.000000    47.750000

# %%
# Check missing values
df.isnull().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
df.dtypes
# Out:
# ID             int64
# No_Pation      int64
# Gender        object
# AGE            int64
# Urea         float64
# Cr             int64
# HbA1c        float64
# Chol         float64
# TG           float64
# HDL          float64
# LDL          float64
# VLDL         float64
# BMI          float64
# CLASS         object
# dtype: object

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Gender', 'CLASS'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Gender'] = le.fit_transform(df['Gender'])
df['CLASS'] = le.fit_transform(df['CLASS'])

# %%
df.dtypes
# Out:
# ID             int64
# No_Pation      int64
# Gender         int64
# AGE            int64
# Urea         float64
# Cr             int64
# HbA1c        float64
# Chol         float64
# TG           float64
# HDL          float64
# LDL          float64
# VLDL         float64
# BMI          float64
# CLASS          int64
# dtype: object

# %%
Q1 = df['BMI'].quantile(0.25)
Q3 = df['BMI'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['BMI'] >= lower_bound) & (df['BMI'] <= upper_bound)]

# %%
from sklearn.preprocessing import MinMaxScaler

minmax_scaler = MinMaxScaler()

df_minmax = df.copy()
df_minmax[df.columns[:-1]] = minmax_scaler.fit_transform(df[df.columns[:-1]])

df_minmax.head()
# Out:
#          ID  No_Pation  Gender       AGE      Urea        Cr     HbA1c  \
# 0  0.627034   0.000237     0.0  0.508475  0.109375  0.050378  0.264901
# 1  0.918648   0.000452     0.5  0.101695  0.104167  0.070529  0.264901
# 2  0.524406   0.000634     0.0  0.508475  0.109375  0.050378  0.264901
# 3  0.849812   0.001160     0.0  0.508475  0.109375  0.050378  0.264901
# 4  0.629537   0.000452     0.5  0.220339  0.171875  0.050378  0.264901
#
#        Chol        TG       HDL       LDL      VLDL       BMI  CLASS
# 0  0.407767  0.044444  0.226804  0.114583  0.011461  0.206186      0
# 1  0.359223  0.081481  0.092784  0.187500  0.014327  0.164948      0
# 2  0.407767  0.044444  0.226804  0.114583  0.011461  0.206186      0
# 3  0.407767  0.044444  0.226804  0.114583  0.011461  0.206186      0
# 4  0.475728  0.051852  0.061856  0.177083  0.008596  0.082474      0

# %%
from sklearn.preprocessing import StandardScaler

standard_scaler = StandardScaler()

df_standard = df.copy()
df_standard[df.columns[:-1]] = standard_scaler.fit_transform(df[df.columns[:-1]])

df_standard.head()
# Out:
#          ID  No_Pation    Gender       AGE      Urea        Cr     HbA1c  \
# 0  0.674235  -0.074824 -1.136658 -0.405184 -0.145871 -0.382316 -1.331894
# 1  1.644599  -0.070023  0.872647 -3.138548 -0.213961 -0.115846 -1.331894
# 2  0.332734  -0.065959 -1.136658 -0.405184 -0.145871 -0.382316 -1.331894
# 3  1.415543  -0.054233 -1.136658 -0.405184 -0.145871 -0.382316 -1.331894
# 4  0.682564  -0.070023  0.872647 -2.341317  0.671204 -0.382316 -1.331894
#
#        Chol        TG       HDL       LDL      VLDL       BMI  CLASS
# 0 -0.507202 -1.034780  1.807759 -1.084134 -0.365466 -1.134109      0
# 1 -0.891621 -0.678221 -0.158783 -0.454716 -0.337797 -1.339384      0
# 2 -0.507202 -1.034780  1.807759 -1.084134 -0.365466 -1.134109      0
# 3 -0.507202 -1.034780  1.807759 -1.084134 -0.365466 -1.134109      0
# 4  0.030985 -0.963468 -0.612600 -0.544633 -0.393135 -1.749933      0
